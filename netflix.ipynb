# %% [markdown]
# <a href="https://colab.research.google.com/github/kintaladhanalaxmi2007-ux/NETFLIX-CASE-STUDIES-DATA-ANALYST/blob/main/netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##NETFLIX

# %% [markdown]
# ##import labraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##Import Raw data

# %%
df=pd.read_excel("/content/NETFLIX DATASET.xlsx")
print(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ##Basic data understandindg

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.size
# Out:
# 105684

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail(5)
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ##CHECK MISSING VALUES

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.dropna()
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df.fillna(0)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water                0
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                0
# 4         s5  TV Show           Kota Factory                0
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb                0
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ##CHECK DUPLICATES

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ##DATA CLEANING

# %%
df[['duration_num','duration_unit']] = df['duration'].str.split(' ', expand=True)
df['duration_num'] = pd.to_numeric(df['duration_num'], errors='coerce')
print(df.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ##CONVERT CATEGORICAL COLUMNS

# %%
cat_cols = ['type','director','cast','rating','duration','listed_in','country']
df[cat_cols] = df[cat_cols].astype('category')
print(df[cat_cols])
# Out:
#          type         director  \
# 0       Movie  Kirsten Johnson
# 1     TV Show              NaN
# 2     TV Show  Julien Leclercq
# 3     TV Show              NaN
# 4     TV Show              NaN
# ...       ...              ...
# 8802    Movie    David Fincher
# 8803  TV Show              NaN
# 8804    Movie  Ruben Fleischer
# 8805    Movie     Peter Hewitt
# 8806    Movie      Mozez Singh
#
#                                                    cast rating   duration  \
# 0                                                   NaN  PG-13     90 min
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  TV-MA  2 Seasons
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  TV-MA   1 Season
# 3                                                   NaN  TV-MA   1 Season
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...  TV-MA  2 Seasons
# ...                                                 ...    ...        ...
# ...

# %% [markdown]
# ##Non_Graphical analysis

# %% [markdown]
# ##value counts of(type)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# ##value counts of(release_year)

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1925       1
# 1959       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# ##Number of unique countries

# %%
df['country'].nunique()
# Out:
# 748

# %% [markdown]
# ##UNIVARIENT ANALYSIS

# %%
plt.figure()
sns.displot(df['release_year'],bins=30,kde=True)
plt.title("Displot release_year")
plt.xlabel("release_year")
plt.ylabel("density")
plt.show()

# %% [markdown]
# ##COUNTPLOT

# %%
plt.figure()
sns.countplot(x=df['type'])
plt.title("countplot type")
plt.show()

# %% [markdown]
# ##HISTOGRAM PLOT

# %%
plt.figure()
sns.histplot(df['rating'],bins=5,kde=True)
plt.title("how_id histplot")
plt.xlabel("rating")
plt.ylabel("realse_year")
plt.show()

# %% [markdown]
# ##BIVARIENT ANALYSIS

# %% [markdown]
# ##BOXPLOT

# %%
plt.figure()
sns.boxplot(x=df['release_year'],y=df['type'])
plt.xlabel='content_type'
plt.ylabel='duration'
plt.title('boxplot on content_type by duration')
# Out:
# Text(0.5, 1.0, 'boxplot on content_type by duration')

# %% [markdown]
# ##HEATMAP

# %%
df['duration'] = df['duration'].astype(str)

df['duration'] = df['duration'].str.extract('(\d+)').astype(float)

corr=df[['release_year','duration']].corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_1055/2911368196.py:3: SyntaxWarning: invalid escape sequence '\d'
#   df['duration'] = df['duration'].str.extract('(\d+)').astype(float)
# <Axes: >

# %% [markdown]
# ##PAIRPLOT

# %%
sns.pairplot(df[['release_year', 'duration']])

# %% [markdown]
# ##MISSING VALUE DETECTION

# %%
df[['rating','type','country']].isnull()
# Out:
#       rating   type  country
# 0      False  False    False
# 1      False  False    False
# 2      False  False     True
# 3      False  False     True
# 4      False  False    False
# ...      ...    ...      ...
# 8802   False  False    False
# 8803   False  False     True
# 8804   False  False    False
# 8805   False  False    False
# 8806   False  False    False
#
# [8807 rows x 3 columns]

# %%
df[['rating','type','country']].isnull().sum()
# Out:
# rating       4
# type         0
# country    831
# dtype: int64

# %% [markdown]
# ##OUTLIER DETECTION

# %%
sns.histplot(x=df['type'])
plt.title(" outlier in type")
plt.show()

# %% [markdown]
# ##BOX plot

# %%
sort=df.sort_values(by='duration',ascending=False).head(100)
sns.boxplot(x=sort['duration'])
plt.title("outliers in duration")
plt.show()
